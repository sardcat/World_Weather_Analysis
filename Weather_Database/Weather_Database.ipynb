# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['main'] + " : " + city_weather['weather'][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 1 | iskateley
# Processing Record 6 of Set 1 | wattegama
# Processing Record 7 of Set 1 | lompoc
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | muscat
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | komsomolskiy
# Processing Record 14 of Set 1 | gat
# Processing Record 15 of Set 1 | cayenne
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | shirokiy
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | almaznyy
# Processing Record 21 of Set 1 | coos bay
# Processing Record 22 of Set 1 | pahrump
# Processing Record 23 of Set 1 | geraldton
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | portland
# Processing Record 27 of Set 1 | pochutla
# Processing Record 28 of Set 1 | ginir
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | oktyabrskoye
# Processing Record 32 of Set 1 | iqaluit
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | sitka
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | kamenka
# Processing Record 44 of Set 1 | coihaique
# Processing Record 45 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 1 | tarnok
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | kahului
# Processing Record 2 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 3 of Set 2 | bestobe
# Processing Record 4 of Set 2 | asyut
# Processing Record 5 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 2 | yongan
# Processing Record 7 of Set 2 | mehamn
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | turukhansk
# Processing Record 10 of Set 2 | deyang
# Processing Record 11 of Set 2 | mao
# Processing Record 12 of Set 2 | gyulahaza
# Processing Record 13 of Set 2 | hualmay
# Processing Record 14 of Set 2 | torbay
# Processing Record 15 of Set 2 | kununurra
# Processing Record 16 of Set 2 | hami
# Processing Record 17 of Set 2 | north bend
# Processing Record 18 of Set 2 | codrington
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | cherskiy
# Processing Record 21 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | saint combs
# City not found. Skipping...
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | faanui
# Processing Record 27 of Set 2 | egvekinot
# Processing Record 28 of Set 2 | shimoda
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | katsuura
# Processing Record 32 of Set 2 | luziania
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | clyde river
# Processing Record 35 of Set 2 | saint george
# Processing Record 36 of Set 2 | huarmey
# Processing Record 37 of Set 2 | oberstdorf
# Processing Record 38 of Set 2 | mount gambier
# Processing Record 39 of Set 2 | itu
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | kadnikov
# Processing Record 42 of Set 2 | bilma
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | klaksvik
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | vardo
# Processing Record 47 of Set 2 | lagoa
# Processing Record 48 of Set 2 | margate
# Processing Record 49 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 2 | mezhdurechensk
# Processing Record 1 of Set 3 | aykhal
# Processing Record 2 of Set 3 | marzuq
# Processing Record 3 of Set 3 | hofn
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | grand gaube
# Processing Record 6 of Set 3 | khobi
# Processing Record 7 of Set 3 | amaraji
# Processing Record 8 of Set 3 | chapais
# Processing Record 9 of Set 3 | mwinilunga
# Processing Record 10 of Set 3 | la ronge
# Processing Record 11 of Set 3 | batagay-alyta
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | huntingdon
# Processing Record 14 of Set 3 | kirovskiy
# Processing Record 15 of Set 3 | port lincoln
# Processing Record 16 of Set 3 | caucaia
# Processing Record 17 of Set 3 | saryg-sep
# Processing Record 18 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 3 | noumea
# Processing Record 20 of Set 3 | avarua
# Processing Record 21 of Set 3 | yumen
# Processing Record 22 of Set 3 | zhigansk
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | groton
# Processing Record 25 of Set 3 | bluff
# Processing Record 26 of Set 3 | xian
# Processing Record 27 of Set 3 | vao
# Processing Record 28 of Set 3 | port blair
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | mercedes
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | moratuwa
# Processing Record 33 of Set 3 | hutchinson
# Processing Record 34 of Set 3 | achisay
# City not found. Skipping...
# Processing Record 35 of Set 3 | ahipara
# Processing Record 36 of Set 3 | pakala
# Processing Record 37 of Set 3 | mar del plata
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | ancud
# Processing Record 40 of Set 3 | beloha
# Processing Record 41 of Set 3 | makakilo city
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | priiskovyy
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | portpatrick
# City not found. Skipping...
# Processing Record 46 of Set 3 | sao felix do xingu
# Processing Record 47 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 48 of Set 3 | fortuna
# Processing Record 49 of Set 3 | svetlogorsk
# Processing Record 50 of Set 3 | hithadhoo
# Processing Record 1 of Set 4 | ust-maya
# Processing Record 2 of Set 4 | santa isabel
# Processing Record 3 of Set 4 | vila
# Processing Record 4 of Set 4 | terney
# Processing Record 5 of Set 4 | nikolskoye
# Processing Record 6 of Set 4 | nelson bay
# Processing Record 7 of Set 4 | dinar
# Processing Record 8 of Set 4 | oskarshamn
# Processing Record 9 of Set 4 | la macarena
# Processing Record 10 of Set 4 | tasiilaq
# Processing Record 11 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 4 | karaj
# Processing Record 13 of Set 4 | nantucket
# Processing Record 14 of Set 4 | padang
# Processing Record 15 of Set 4 | port hawkesbury
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | san quintin
# Processing Record 18 of Set 4 | muros
# Processing Record 19 of Set 4 | mogadishu
# Processing Record 20 of Set 4 | vaitape
# Processing Record 21 of Set 4 | namibe
# Processing Record 22 of Set 4 | leduc
# Processing Record 23 of Set 4 | banda aceh
# Processing Record 24 of Set 4 | conde
# Processing Record 25 of Set 4 | abu samrah
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | ocos
# Processing Record 28 of Set 4 | nioro
# Processing Record 29 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 30 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | krosno
# Processing Record 33 of Set 4 | ambam
# Processing Record 34 of Set 4 | okha
# Processing Record 35 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 4 | amapa
# Processing Record 38 of Set 4 | nanortalik
# Processing Record 39 of Set 4 | albesti
# Processing Record 40 of Set 4 | kulhudhuffushi
# Processing Record 41 of Set 4 | gusau
# Processing Record 42 of Set 4 | kasulu
# Processing Record 43 of Set 4 | sokolo
# Processing Record 44 of Set 4 | kavieng
# Processing Record 45 of Set 4 | provideniya
# Processing Record 46 of Set 4 | monrovia
# Processing Record 47 of Set 4 | ambilobe
# Processing Record 48 of Set 4 | georgetown
# Processing Record 49 of Set 4 | pasni
# Processing Record 50 of Set 4 | colesberg
# Processing Record 1 of Set 5 | ponta do sol
# Processing Record 2 of Set 5 | peniche
# Processing Record 3 of Set 5 | ostrovnoy
# Processing Record 4 of Set 5 | puri
# Processing Record 5 of Set 5 | marsa matruh
# Processing Record 6 of Set 5 | airai
# Processing Record 7 of Set 5 | salalah
# Processing Record 8 of Set 5 | palmer
# Processing Record 9 of Set 5 | rio brilhante
# Processing Record 10 of Set 5 | hauterive
# Processing Record 11 of Set 5 | san vicente
# Processing Record 12 of Set 5 | anadyr
# Processing Record 13 of Set 5 | avera
# Processing Record 14 of Set 5 | saint anthony
# Processing Record 15 of Set 5 | shu
# Processing Record 16 of Set 5 | shadegan
# Processing Record 17 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 5 | sandwick
# Processing Record 20 of Set 5 | osa
# Processing Record 21 of Set 5 | veraval
# Processing Record 22 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | mackay
# Processing Record 25 of Set 5 | borogontsy
# Processing Record 26 of Set 5 | tuktoyaktuk
# Processing Record 27 of Set 5 | concordia
# Processing Record 28 of Set 5 | khatanga
# Processing Record 29 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 5 | pisco
# Processing Record 31 of Set 5 | englewood
# Processing Record 32 of Set 5 | arroyos y esteros
# Processing Record 33 of Set 5 | jumla
# Processing Record 34 of Set 5 | la orilla
# Processing Record 35 of Set 5 | beringovskiy
# Processing Record 36 of Set 5 | zhuhai
# Processing Record 37 of Set 5 | kizukuri
# Processing Record 38 of Set 5 | awjilah
# Processing Record 39 of Set 5 | ossora
# Processing Record 40 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 5 | zanatepec
# City not found. Skipping...
# Processing Record 42 of Set 5 | two rivers
# Processing Record 43 of Set 5 | san patricio
# Processing Record 44 of Set 5 | fort william
# Processing Record 45 of Set 5 | innisfail
# Processing Record 46 of Set 5 | souillac
# Processing Record 47 of Set 5 | sisimiut
# Processing Record 48 of Set 5 | biak
# Processing Record 49 of Set 5 | mongoumba
# Processing Record 50 of Set 5 | oranjemund
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | constitucion
# Processing Record 3 of Set 6 | union de tula
# Processing Record 4 of Set 6 | sweetwater
# Processing Record 5 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 6 | florianopolis
# Processing Record 7 of Set 6 | sarh
# Processing Record 8 of Set 6 | hamilton
# Processing Record 9 of Set 6 | rocha
# Processing Record 10 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 6 | cognac
# Processing Record 12 of Set 6 | shelburne
# Processing Record 13 of Set 6 | la reforma
# Processing Record 14 of Set 6 | shitanjing
# Processing Record 15 of Set 6 | kuytun
# Processing Record 16 of Set 6 | vestmannaeyjar
# Processing Record 17 of Set 6 | same
# Processing Record 18 of Set 6 | mareeba
# Processing Record 19 of Set 6 | murray bridge
# Processing Record 20 of Set 6 | krasnyy yar
# Processing Record 21 of Set 6 | karratha
# Processing Record 22 of Set 6 | baykit
# Processing Record 23 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 6 | pevek
# Processing Record 25 of Set 6 | bongor
# Processing Record 26 of Set 6 | richards bay
# Processing Record 27 of Set 6 | payson
# Processing Record 28 of Set 6 | tuatapere
# Processing Record 29 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 6 | wanparti
# Processing Record 31 of Set 6 | svetlaya
# Processing Record 32 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 6 | san blas
# Processing Record 34 of Set 6 | flin flon
# Processing Record 35 of Set 6 | ilulissat
# Processing Record 36 of Set 6 | akdepe
# Processing Record 37 of Set 6 | presidencia roque saenz pena
# Processing Record 38 of Set 6 | chicama
# Processing Record 39 of Set 6 | lazaro cardenas
# Processing Record 40 of Set 6 | guerrero negro
# Processing Record 41 of Set 6 | manta
# Processing Record 42 of Set 6 | putina
# Processing Record 43 of Set 6 | ngunguru
# Processing Record 44 of Set 6 | dejen
# Processing Record 45 of Set 6 | inhambane
# Processing Record 46 of Set 6 | neiafu
# Processing Record 47 of Set 6 | sangar
# Processing Record 48 of Set 6 | kodiak
# Processing Record 49 of Set 6 | kjollefjord
# Processing Record 50 of Set 6 | alofi
# Processing Record 1 of Set 7 | te anau
# Processing Record 2 of Set 7 | bubaque
# Processing Record 3 of Set 7 | kokkola
# Processing Record 4 of Set 7 | deer lake
# Processing Record 5 of Set 7 | prince rupert
# Processing Record 6 of Set 7 | sterling
# Processing Record 7 of Set 7 | betare oya
# Processing Record 8 of Set 7 | eirunepe
# Processing Record 9 of Set 7 | olafsvik
# Processing Record 10 of Set 7 | bundaberg
# Processing Record 11 of Set 7 | scottsbluff
# Processing Record 12 of Set 7 | la palma
# Processing Record 13 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 7 | ouesso
# Processing Record 15 of Set 7 | samarai
# Processing Record 16 of Set 7 | kristiinankaupunki
# Processing Record 17 of Set 7 | peyima
# Processing Record 18 of Set 7 | poum
# Processing Record 19 of Set 7 | porto velho
# Processing Record 20 of Set 7 | dunda
# Processing Record 21 of Set 7 | nome
# Processing Record 22 of Set 7 | dolores
# Processing Record 23 of Set 7 | yulara
# Processing Record 24 of Set 7 | husavik
# Processing Record 25 of Set 7 | srednekolymsk
# Processing Record 26 of Set 7 | ola
# Processing Record 27 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 28 of Set 7 | sabang
# Processing Record 29 of Set 7 | carballo
# Processing Record 30 of Set 7 | coquimbo
# Processing Record 31 of Set 7 | severo-kurilsk
# Processing Record 32 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 7 | nipawin
# Processing Record 34 of Set 7 | hambantota
# Processing Record 35 of Set 7 | cordoba
# Processing Record 36 of Set 7 | roma
# Processing Record 37 of Set 7 | andreapol
# Processing Record 38 of Set 7 | saldanha
# Processing Record 39 of Set 7 | hirara
# Processing Record 40 of Set 7 | cabo san lucas
# Processing Record 41 of Set 7 | berbera
# Processing Record 42 of Set 7 | anamur
# Processing Record 43 of Set 7 | panguna
# Processing Record 44 of Set 7 | sonoita
# Processing Record 45 of Set 7 | pacific grove
# Processing Record 46 of Set 7 | krasnouralsk
# Processing Record 47 of Set 7 | cap malheureux
# Processing Record 48 of Set 7 | jining
# Processing Record 49 of Set 7 | tsumeb
# Processing Record 50 of Set 7 | vila franca do campo
# Processing Record 1 of Set 8 | sinnamary
# Processing Record 2 of Set 8 | pandan
# Processing Record 3 of Set 8 | luganville
# Processing Record 4 of Set 8 | along
# Processing Record 5 of Set 8 | cockburn town
# Processing Record 6 of Set 8 | ixtapa
# Processing Record 7 of Set 8 | ondjiva
# Processing Record 8 of Set 8 | carutapera
# Processing Record 9 of Set 8 | bafq
# Processing Record 10 of Set 8 | nicholasville
# Processing Record 11 of Set 8 | chaa-khol
# City not found. Skipping...
# Processing Record 12 of Set 8 | grand forks
# Processing Record 13 of Set 8 | sorland
# Processing Record 14 of Set 8 | chaozhou
# Processing Record 15 of Set 8 | brae
# Processing Record 16 of Set 8 | manoel urbano
# Processing Record 17 of Set 8 | vilhena
# Processing Record 18 of Set 8 | bagdarin
# Processing Record 19 of Set 8 | arlit
# Processing Record 20 of Set 8 | san policarpo
# Processing Record 21 of Set 8 | quatre cocos
# Processing Record 22 of Set 8 | kieta
# Processing Record 23 of Set 8 | harper
# Processing Record 24 of Set 8 | darab
# Processing Record 25 of Set 8 | panaba
# Processing Record 26 of Set 8 | mtwara
# Processing Record 27 of Set 8 | marapanim
# Processing Record 28 of Set 8 | seymchan
# Processing Record 29 of Set 8 | batemans bay
# Processing Record 30 of Set 8 | iquique
# Processing Record 31 of Set 8 | longyearbyen
# Processing Record 32 of Set 8 | yamasaki
# Processing Record 33 of Set 8 | port-cartier
# Processing Record 34 of Set 8 | sao miguel do tapuio
# Processing Record 35 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 36 of Set 8 | touros
# Processing Record 37 of Set 8 | ati
# Processing Record 38 of Set 8 | berlevag
# Processing Record 39 of Set 8 | deputatskiy
# Processing Record 40 of Set 8 | sunrise manor
# Processing Record 41 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 8 | zamora
# Processing Record 43 of Set 8 | newport
# Processing Record 44 of Set 8 | puerto concordia
# Processing Record 45 of Set 8 | pimenta bueno
# Processing Record 46 of Set 8 | marawi
# Processing Record 47 of Set 8 | san angelo
# Processing Record 48 of Set 8 | meulaboh
# Processing Record 49 of Set 8 | rio blanco
# Processing Record 50 of Set 8 | bereda
# Processing Record 1 of Set 9 | dali
# Processing Record 2 of Set 9 | jalu
# Processing Record 3 of Set 9 | gangarampur
# Processing Record 4 of Set 9 | tommot
# Processing Record 5 of Set 9 | windhoek
# Processing Record 6 of Set 9 | tazovskiy
# Processing Record 7 of Set 9 | labuhan
# Processing Record 8 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 9 of Set 9 | cuitlahuac
# Processing Record 10 of Set 9 | lasa
# Processing Record 11 of Set 9 | sao miguel do araguaia
# Processing Record 12 of Set 9 | kresttsy
# Processing Record 13 of Set 9 | maragogi
# Processing Record 14 of Set 9 | ukiah
# Processing Record 15 of Set 9 | payakumbuh
# Processing Record 16 of Set 9 | provins
# Processing Record 17 of Set 9 | hasaki
# Processing Record 18 of Set 9 | atar
# Processing Record 19 of Set 9 | glens falls
# Processing Record 20 of Set 9 | siutu
# City not found. Skipping...
# Processing Record 21 of Set 9 | tual
# Processing Record 22 of Set 9 | sechura
# Processing Record 23 of Set 9 | kutum
# Processing Record 24 of Set 9 | papara
# Processing Record 25 of Set 9 | balabac
# Processing Record 26 of Set 9 | ust-omchug
# Processing Record 27 of Set 9 | batagay
# Processing Record 28 of Set 9 | el vigia
# Processing Record 29 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 9 | valparaiso
# Processing Record 31 of Set 9 | champerico
# Processing Record 32 of Set 9 | chibuto
# Processing Record 33 of Set 9 | ust-barguzin
# Processing Record 34 of Set 9 | rabo de peixe
# Processing Record 35 of Set 9 | port-gentil
# Processing Record 36 of Set 9 | benguela
# Processing Record 37 of Set 9 | shchors
# Processing Record 38 of Set 9 | kokopo
# Processing Record 39 of Set 9 | siguiri
# Processing Record 40 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 9 | taperoa
# Processing Record 42 of Set 9 | lyuban
# Processing Record 43 of Set 9 | henties bay
# Processing Record 44 of Set 9 | hay river
# Processing Record 45 of Set 9 | rawson
# Processing Record 46 of Set 9 | kaeo
# Processing Record 47 of Set 9 | inta
# Processing Record 48 of Set 9 | nichinan
# Processing Record 49 of Set 9 | auce
# Processing Record 50 of Set 9 | hailar
# Processing Record 1 of Set 10 | broome
# Processing Record 2 of Set 10 | port shepstone
# Processing Record 3 of Set 10 | florencia
# Processing Record 4 of Set 10 | mizan teferi
# Processing Record 5 of Set 10 | urucui
# Processing Record 6 of Set 10 | tigil
# Processing Record 7 of Set 10 | maarianhamina
# Processing Record 8 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 9 of Set 10 | killybegs
# Processing Record 10 of Set 10 | kibaya
# Processing Record 11 of Set 10 | caranavi
# Processing Record 12 of Set 10 | yar-sale
# Processing Record 13 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 10 | nizhneangarsk
# Processing Record 15 of Set 10 | lavrentiya
# Processing Record 16 of Set 10 | puerto carreno
# Processing Record 17 of Set 10 | crestview
# Processing Record 18 of Set 10 | gillette
# Processing Record 19 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 20 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 21 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 22 of Set 10 | astana
# Processing Record 23 of Set 10 | krasnoarmeysk
# Processing Record 24 of Set 10 | thuro
# City not found. Skipping...
# Processing Record 25 of Set 10 | brattleboro
# Processing Record 26 of Set 10 | salekhard
# Processing Record 27 of Set 10 | bandundu
# Processing Record 28 of Set 10 | ust-kut
# Processing Record 29 of Set 10 | puerto escondido
# Processing Record 30 of Set 10 | ozernovskiy
# Processing Record 31 of Set 10 | aklavik
# Processing Record 32 of Set 10 | saint-augustin
# Processing Record 33 of Set 10 | goose creek
# Processing Record 34 of Set 10 | faya
# Processing Record 35 of Set 10 | ribeira brava
# Processing Record 36 of Set 10 | russell
# Processing Record 37 of Set 10 | shar
# Processing Record 38 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 10 | acapetahua
# Processing Record 40 of Set 10 | novoagansk
# Processing Record 41 of Set 10 | alice springs
# Processing Record 42 of Set 10 | ostersund
# Processing Record 43 of Set 10 | magistralnyy
# Processing Record 44 of Set 10 | haslev
# Processing Record 45 of Set 10 | iracoubo
# Processing Record 46 of Set 10 | shingu
# Processing Record 47 of Set 10 | ploemeur
# Processing Record 48 of Set 10 | golden
# Processing Record 49 of Set 10 | nizwa
# Processing Record 50 of Set 10 | ahuimanu
# Processing Record 1 of Set 11 | eureka
# Processing Record 2 of Set 11 | motygino
# Processing Record 3 of Set 11 | hobbs
# Processing Record 4 of Set 11 | ust-ishim
# Processing Record 5 of Set 11 | san cristobal
# Processing Record 6 of Set 11 | pangai
# Processing Record 7 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 11 | bireun
# Processing Record 9 of Set 11 | evensk
# Processing Record 10 of Set 11 | vanimo
# Processing Record 11 of Set 11 | talnakh
# Processing Record 12 of Set 11 | agadez
# Processing Record 13 of Set 11 | chiang khong
# Processing Record 14 of Set 11 | san luis
# Processing Record 15 of Set 11 | pangkalanbuun
# Processing Record 16 of Set 11 | hindoria
# Processing Record 17 of Set 11 | deniliquin
# Processing Record 18 of Set 11 | asosa
# Processing Record 19 of Set 11 | ponta delgada
# Processing Record 20 of Set 11 | guadix
# Processing Record 21 of Set 11 | sawtell
# Processing Record 22 of Set 11 | san rafael
# Processing Record 23 of Set 11 | apac
# Processing Record 24 of Set 11 | ojinaga
# Processing Record 25 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 26 of Set 11 | pinega
# Processing Record 27 of Set 11 | angoche
# Processing Record 28 of Set 11 | pundaguitan
# Processing Record 29 of Set 11 | lorengau
# Processing Record 30 of Set 11 | asau
# Processing Record 31 of Set 11 | porto novo
# Processing Record 32 of Set 11 | caravelas
# Processing Record 33 of Set 11 | majenang
# Processing Record 34 of Set 11 | college
# Processing Record 35 of Set 11 | bella union
# Processing Record 36 of Set 11 | mangrul pir
# Processing Record 37 of Set 11 | ballina
# Processing Record 38 of Set 11 | muriwai beach
# Processing Record 39 of Set 11 | mogzon
# Processing Record 40 of Set 11 | bogorodskoye
# Processing Record 41 of Set 11 | borlange
# City not found. Skipping...
# Processing Record 42 of Set 11 | praia
# Processing Record 43 of Set 11 | acajutla
# Processing Record 44 of Set 11 | namtsy
# Processing Record 45 of Set 11 | chiang rai
# Processing Record 46 of Set 11 | matay
# Processing Record 47 of Set 11 | oltu
# Processing Record 48 of Set 11 | broken hill
# Processing Record 49 of Set 11 | tiznit
# Processing Record 50 of Set 11 | gejiu
# Processing Record 1 of Set 12 | grindavik
# Processing Record 2 of Set 12 | walvis bay
# Processing Record 3 of Set 12 | jaciara
# Processing Record 4 of Set 12 | berdigestyakh
# Processing Record 5 of Set 12 | wewak
# Processing Record 6 of Set 12 | kunjah
# Processing Record 7 of Set 12 | jujuy
# City not found. Skipping...
# Processing Record 8 of Set 12 | los llanos de aridane
# Processing Record 9 of Set 12 | todos santos
# Processing Record 10 of Set 12 | gravdal
# Processing Record 11 of Set 12 | aguia branca
# Processing Record 12 of Set 12 | nizhniy kuranakh
# Processing Record 13 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 14 of Set 12 | sao filipe
# Processing Record 15 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 12 | kozova
# Processing Record 17 of Set 12 | fort nelson
# Processing Record 18 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 19 of Set 12 | general pico
# Processing Record 20 of Set 12 | xining
# Processing Record 21 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 12 | leningradskiy
# Processing Record 24 of Set 12 | baillif
# Processing Record 25 of Set 12 | nisia floresta
# Processing Record 26 of Set 12 | aranda de duero
# Processing Record 27 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 12 | aswan
# Processing Record 29 of Set 12 | bell ville
# Processing Record 30 of Set 12 | nuevitas
# Processing Record 31 of Set 12 | toora-khem
# Processing Record 32 of Set 12 | jiayuguan
# Processing Record 33 of Set 12 | san felipe
# Processing Record 34 of Set 12 | ta khmau
# Processing Record 35 of Set 12 | nargana
# Processing Record 36 of Set 12 | batesville
# Processing Record 37 of Set 12 | raudeberg
# Processing Record 38 of Set 12 | blatnica
# Processing Record 39 of Set 12 | picos
# Processing Record 40 of Set 12 | flinders
# Processing Record 41 of Set 12 | dunedin
# Processing Record 42 of Set 12 | verkhoyansk
# Processing Record 43 of Set 12 | shenjiamen
# Processing Record 44 of Set 12 | rio gallegos
# Processing Record 45 of Set 12 | kendari
# Processing Record 46 of Set 12 | vinh
# Processing Record 47 of Set 12 | shubarshi
# Processing Record 48 of Set 12 | algiers
# Processing Record 49 of Set 12 | cristalina
# Processing Record 50 of Set 12 | maridi
# Processing Record 1 of Set 13 | tokur
# Processing Record 2 of Set 13 | sistranda
# Processing Record 3 of Set 13 | williams lake
# Processing Record 4 of Set 13 | marienburg
# Processing Record 5 of Set 13 | valentigney
# Processing Record 6 of Set 13 | entre rios
# Processing Record 7 of Set 13 | sabla
# Processing Record 8 of Set 13 | kushmurun
# Processing Record 9 of Set 13 | pakxan
# Processing Record 10 of Set 13 | lac du bonnet
# Processing Record 11 of Set 13 | tura
# Processing Record 12 of Set 13 | eravur
# Processing Record 13 of Set 13 | bathurst
# Processing Record 14 of Set 13 | panacan
# Processing Record 15 of Set 13 | naryan-mar
# Processing Record 16 of Set 13 | akdagmadeni
# Processing Record 17 of Set 13 | shiyan
# Processing Record 18 of Set 13 | krasnoselkup
# Processing Record 19 of Set 13 | tongliao
# Processing Record 20 of Set 13 | bertogne
# Processing Record 21 of Set 13 | waipawa
# Processing Record 22 of Set 13 | oriximina
# Processing Record 23 of Set 13 | bambanglipuro
# Processing Record 24 of Set 13 | beni
# Processing Record 25 of Set 13 | tailai
# Processing Record 26 of Set 13 | isiro
# Processing Record 27 of Set 13 | baker city
# Processing Record 28 of Set 13 | qinzhou
# Processing Record 29 of Set 13 | mabaruma
# Processing Record 30 of Set 13 | kazerun
# Processing Record 31 of Set 13 | port hardy
# Processing Record 32 of Set 13 | casablanca
# Processing Record 33 of Set 13 | narsaq
# Processing Record 34 of Set 13 | santa cruz del sur
# Processing Record 35 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 13 | kuito
# Processing Record 37 of Set 13 | abha
# Processing Record 38 of Set 13 | west wendover
# Processing Record 39 of Set 13 | vikulovo
# Processing Record 40 of Set 13 | kousseri
# Processing Record 41 of Set 13 | puerto baquerizo moreno
# Processing Record 42 of Set 13 | gurupa
# Processing Record 43 of Set 13 | acarau
# Processing Record 44 of Set 13 | chunhuhub
# Processing Record 45 of Set 13 | polunochnoye
# Processing Record 46 of Set 13 | naze
# Processing Record 47 of Set 13 | carlisle
# Processing Record 48 of Set 13 | colac
# Processing Record 49 of Set 13 | namatanai
# Processing Record 50 of Set 13 | jiwani
# Processing Record 1 of Set 14 | oxapampa
# Processing Record 2 of Set 14 | saint-francois
# Processing Record 3 of Set 14 | mutare
# Processing Record 4 of Set 14 | acapulco
# Processing Record 5 of Set 14 | sioux lookout
# Processing Record 6 of Set 14 | pak phanang
# Processing Record 7 of Set 14 | mantua
# Processing Record 8 of Set 14 | surgut
# Processing Record 9 of Set 14 | birjand
# Processing Record 10 of Set 14 | kruisfontein
# Processing Record 11 of Set 14 | fairbanks
# Processing Record 12 of Set 14 | kouango
# Processing Record 13 of Set 14 | vostok
# Processing Record 14 of Set 14 | skelleftea
# Processing Record 15 of Set 14 | mnogovershinnyy
# Processing Record 16 of Set 14 | half moon bay
# Processing Record 17 of Set 14 | fare
# Processing Record 18 of Set 14 | bati
# Processing Record 19 of Set 14 | kommunisticheskiy
# Processing Record 20 of Set 14 | alasehir
# Processing Record 21 of Set 14 | agirish
# Processing Record 22 of Set 14 | lebedinyy
# Processing Record 23 of Set 14 | sao joao da barra
# Processing Record 24 of Set 14 | necochea
# Processing Record 25 of Set 14 | terrace
# Processing Record 26 of Set 14 | byron bay
# Processing Record 27 of Set 14 | marystown
# Processing Record 28 of Set 14 | bathsheba
# Processing Record 29 of Set 14 | tiarei
# Processing Record 30 of Set 14 | dwarka
# Processing Record 31 of Set 14 | zharkent
# Processing Record 32 of Set 14 | itapaci
# Processing Record 33 of Set 14 | augusto correa
# Processing Record 34 of Set 14 | shiraz
# Processing Record 35 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 36 of Set 14 | sovetskiy
# Processing Record 37 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 14 | giraldo
# Processing Record 39 of Set 14 | skjervoy
# Processing Record 40 of Set 14 | eyl
# Processing Record 41 of Set 14 | charlottetown
# Processing Record 42 of Set 14 | yuryevets
# Processing Record 43 of Set 14 | khandyga
# Processing Record 44 of Set 14 | nyurba
# Processing Record 45 of Set 14 | rossland
# Processing Record 46 of Set 14 | ugoofaaru
# Processing Record 47 of Set 14 | de-kastri
# Processing Record 48 of Set 14 | ganzhou
# Processing Record 49 of Set 14 | kloulklubed
# Processing Record 50 of Set 14 | buchanan
# Processing Record 1 of Set 15 | krasnokholmskiy
# Processing Record 2 of Set 15 | kihei
# Processing Record 3 of Set 15 | parintins
# Processing Record 4 of Set 15 | paraiso
# Processing Record 5 of Set 15 | oban
# Processing Record 6 of Set 15 | socorro
# Processing Record 7 of Set 15 | najran
# Processing Record 8 of Set 15 | zyryanka
# Processing Record 9 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 10 of Set 15 | truro
# Processing Record 11 of Set 15 | manggar
# Processing Record 12 of Set 15 | ciudad guayana
# Processing Record 13 of Set 15 | talavera
# Processing Record 14 of Set 15 | rudnogorsk
# Processing Record 15 of Set 15 | visby
# Processing Record 16 of Set 15 | oktyabrskiy
# Processing Record 17 of Set 15 | maceio
# Processing Record 18 of Set 15 | pilot butte
# Processing Record 19 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 15 | sibay
# Processing Record 21 of Set 15 | payo
# Processing Record 22 of Set 15 | finnsnes
# Processing Record 23 of Set 15 | road town
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 662

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saskylakh      RU  71.9167  114.0833    -29.67       100          85
# 1   Upernavik      GL  72.7868  -56.1549      0.43        98         100
# 2  Butaritari      KI   3.0707  172.7902     82.38        69          14
# 3   Iskateley      RU  67.6803   53.1512     -7.87        98          86
# 4   Wattegama      LK   6.7989   81.4808     69.58        91           6
# 5      Lompoc      US  34.6391 -120.4579     66.13        49           0
# 6     Ushuaia      AR -54.8000  -68.3000     64.02        39          40
# 7   Jamestown      US  42.0970  -79.2353     19.53        48          75
# 8      Muscat      OM  23.6139   58.5922     73.42        55          15
# 9    Hermanus      ZA -34.4187   19.2345     85.89        64          62
#
#    Wind Speed        Current Description
# 0        4.41   Clouds : overcast clouds
# 1        4.56   Clouds : overcast clouds
# 2       18.14        Clouds : few clouds
# 3        9.55   Clouds : overcast clouds
# 4        5.35          Clear : clear sky
# 5        6.91          Clear : clear sky
# 6       12.66  Clouds : scattered clouds
# 7        5.99     Clouds : broken clouds
# 8        3.65        Clouds : few clouds
# 9       20.15     Clouds : broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
